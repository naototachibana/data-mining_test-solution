# %% [markdown]
# # データマイニング・可視化特論Ⅰ 担当：青野先生
# ##2019/06/06 実施
#
# ## テストに関して
# プリント，ノート，PC持ち込み可
#
# →テスト問題を解く AI を持ち込んで代わりに回答させれば良いのでは ?
#
# ## 注意
#
# うろ覚えの問題を書き起こしているため，完全に出た問題と一致しているわけではない．
#
# ## 受けた所見
#
# 非常に難しい．日頃から機械学習やNNをもちいて研究していればいけたのかなと．
# 私は爆発四散しました．サヨナラ！
#
# ### 1 ニューラルネットワークについての知識を問われる問題
#
# 1. 全結合型ニューラルネットワーク(FC)，CNN，RNNの特徴，利点，欠点を簡潔に説明せよ (語群から一回以上使用)
# 　　覚えている語群（１次元、２次元、３次元、空間的局所性、時間的局所性、VGG16、過学習、ドロップアウト、勾配消失、勾配爆発、LSTM、多層化、時系列）
#
#  -
#  -
#  -
#
# 2. 訓練データ テストデータ バリデーションデータをそれぞれどれくらいの割合で学習させてやるのがよいか？ また、その割合にした理由と、バリデーションする理由（利点？）は？(画像10万データとする)
#
#  - 6:2:2 くらい?
#
# 3. 上記の割合にしたとき，ニューラルネットワークにはどの活性化関数をもちいればよいか．
# また，全体の損失関数は何を使えばよいか．
#  - 活性化関数 : tanh, sigmoid, ReLU, LeakyReLU
#  - 損失関数 MSE, 交差エントロピー誤差
#
# ### 2 Amazonレビューの星の数字を予測
# 1. 仮定するカテゴリーを書け
#  - 例：ゲーム、書籍
# 2. 使えそうな特徴量（素性）を5つ挙げよ
# 3. 上記の特徴量に使える回帰モデルを2つ挙げよ
#  - 例：単回帰モデルなどだが素性が２つ以上のため今回は相応しくない）
# 4. 特徴量が有効であることを調べるためにはどうすればよいか
# 5. 回帰モデルを評価するにはどんな手法がある？
#  - （例：...が（大きい／小さい）ほど（良い／悪い））
#
# ### 3 有向グラフが示してあり，それにHITSを適用する．
#
# ![question3](https://github.com/naototachibana/data-mining_test-solution/blob/master/question3.jpg?raw=1)
#
# 1. 隣接行列Eを求めよ．
# 2. hub行列 authority行列を求めよ．
# 3. HITSのアルゴリズムを適用して，各ノードの順位をつけよ．（例：A=D>B>C）
#
#
# ### 4 (a,b,c,d...)と単語のカテゴリが与えられたとき，（１つの単語に複数ラベルが当てられ、ラベル種類は50以上）
#
# 1. どういうデータ群にしたい？
# 2. どんな～～～器を使えばいい？
# →BoWを使用したいので、SVM(サポートベクトルマシン)を使えばよい
# 3. どんな評価をすればよいか？
# →適合率や再現率を計算して、F値を求めればよい
# 4. 教師なしデータの場合どんなクラスタリングを使えばよいか？
